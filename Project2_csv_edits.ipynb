# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://query.data.world/s/ckxg7aq4znw42ekv7vsndyq2ztj776')

# %%
df.head()
# Out:
#                                              summary              city state  \
# 0  Three saucer shaped ships.  High in the sky, m...             Salem    OR
# 1  Tear-drop shaped silent craft with sectional f...         Ellsworth    ME
# 2  Green orb shot out of white light  ((NUFORC No...       San Antonio    TX
# 3  Saw three circular orange lights traveling sou...  Port Saint Lucie    FL
# 4  Light moving slowly thru the sky towards the W...         Whitefish    MT
#
#              date_time     shape    duration  \
# 0                  NaN      disk  15 minutes
# 1                  NaN  teardrop   5 minutes
# 2  2017-01-25T20:45:00     light  90 minutes
# 3  2017-02-24T20:45:00    circle   5 minutes
# 4  2017-02-22T21:00:00     light  15 minutes
#
#                                                stats  \
# 0  Occurred : 8/15/1950 14:00  (Entered as : 08/1...
# 1  Occurred : 8/15/1967 21:30  (Entered as : 08/0...
# 2  Occurred : 1/25/2017 20:45  (Entered as : 01/2...
# ...

# %%
# drop rows with no lat or lng
ufo_locs = df.dropna(axis=0, how='any', thresh=None, subset=['city_latitude'], inplace=False)

# %%
ufo_locs = df.dropna(axis=0, how='any', thresh=None, subset=['city_longitude'], inplace=False)

# %%
ufo_locs.head(30)
# Out:
#                                               summary              city state  \
# 0   Three saucer shaped ships.  High in the sky, m...             Salem    OR
# 1   Tear-drop shaped silent craft with sectional f...         Ellsworth    ME
# 2   Green orb shot out of white light  ((NUFORC No...       San Antonio    TX
# 3   Saw three circular orange lights traveling sou...  Port Saint Lucie    FL
# 4   Light moving slowly thru the sky towards the W...         Whitefish    MT
# 6                        ((HOAX??))  Loud boom heard.           Duxbury    MA
# 7   Two erratic bright white lights seen in Southe...       Studio City    CA
# 8   There was only one UFO.  It was yellow orange-...          Hernando    FL
# 10  Two UFOs over Rockville, MD.  ((anonymous repo...         Rockville    MD
# 12  Bright falling object falls in a direct line t...          Redlands    CA
# 13  Friday march 10th 2017. There was a White ligh...        Alexandria    IN
# ...

# %%
ufo_locs.to_csv('ufo_sighting_locations.csv')
